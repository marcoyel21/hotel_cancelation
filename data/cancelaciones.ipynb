# %%
import numpy as np              # numerical python
import pandas as pd             # dealing with dataframes (excel-like tables)
import matplotlib.pyplot as plt # Basic plots
import seaborn as sns

# %%
df = pd.read_csv('entrena.csv')
print(df.shape)
df.head()
# Out:
# (91531, 30)
#           hotel   is_canceled  lead_time  arrival_date_year  \
# 0  Resort Hotel  no_cancelado        342               2015
# 1  Resort Hotel  no_cancelado        737               2015
# 2  Resort Hotel  no_cancelado          7               2015
# 3  Resort Hotel  no_cancelado         13               2015
# 4  Resort Hotel  no_cancelado         14               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# 1                        0                     0       2  ...
# 2                        0                     1       1  ...
# 3                        0                     1       1  ...
# 4                        0                     2       2  ...
#
#    assigned_room_type  booking_changes deposit_type  agent company  \
# 0                   C                3   No Deposit    NaN     NaN
# 1                   C                4   No Deposit    NaN     NaN
# 2                   C                0   No Deposit    NaN     NaN
# 3                   A                0   No Deposit  304.0     NaN
# 4                   A                0   No Deposit  240.0     NaN
#
#   days_in_waiting_list  customer_type   adr  required_car_parking_spaces  \
# 0                    0      Transient   0.0                            0
# 1                    0      Transient   0.0                            0
# 2                    0      Transient  75.0                            0
# 3                    0      Transient  75.0                            0
# 4                    0      Transient  98.0                            0
#
#   total_of_special_requests
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         1
#
# [5 rows x 30 columns]

# %%
# Print info
# ==Q== ¿Para que sirve el método info() de pandas?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91531 entries, 0 to 91530
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           91531 non-null  object
#  1   is_canceled                     91531 non-null  object
#  2   lead_time                       91531 non-null  int64
#  3   arrival_date_year               91531 non-null  int64
#  4   arrival_date_month              91531 non-null  object
#  5   arrival_date_week_number        91531 non-null  int64
#  6   arrival_date_day_of_month       91531 non-null  int64
#  7   stays_in_weekend_nights         91531 non-null  int64
#  8   stays_in_week_nights            91531 non-null  int64
#  9   adults                          91531 non-null  int64
#  10  children                        91527 non-null  float64
#  11  babies                          91531 non-null  int64
#  12  meal                            91531 non-null  object
#  13  country                         91063 non-null  object
#  14  market_segment                  91531 non-null  object
#  15  distribution_channel            91531 non-null  object
#  16  is_repeated_guest               91531 non-null  int64
#  17  previous_cancellations          91531 non-null  int64
#  18  previous_bookings_not_canceled  91531 non-null  int64
#  19  reserved_room_type              91531 non-null  object
#  20  assigned_room_type              91531 non-null  object
#  21  booking_changes                 91531 non-null  int64
#  22  deposit_type                    91531 non-null  object
#  23  agent                           78314 non-null  float64
#  24  company                         5614 non-null   float64
#  25  days_in_waiting_list            91531 non-null  int64
#  26  customer_type                   91531 non-null  object
#  27  adr                             91531 non-null  float64
#  28  required_car_parking_spaces     91531 non-null  int64
#  29  total_of_special_requests       91531 non-null  int64
# dtypes: float64(4), int64(15), object(11)
# memory usage: 20.9+ MB

# %%
# Print a statistical summary
# ==Q== ¿Qué información proporciona el método describe() de pandas?
df.describe()
# Out:
#           lead_time  arrival_date_year  arrival_date_week_number  \
# count  91531.000000       91531.000000              91531.000000
# mean      96.286843        2015.899837                 28.183621
# std      105.454726           0.608632                 15.012139
# min        0.000000        2015.000000                  1.000000
# 25%       15.000000        2016.000000                 13.000000
# 50%       58.000000        2016.000000                 31.000000
# 75%      145.000000        2016.000000                 41.000000
# max      737.000000        2017.000000                 53.000000
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count               91531.000000             91531.000000
# mean                   15.814063                 0.899291
# std                     8.758629                 1.004555
# min                     1.000000                 0.000000
# 25%                     8.000000                 0.000000
# 50%                    16.000000                 1.000000
# 75%                    23.000000                 2.000000
# max                    31.000000                19.000000
#
#        stays_in_week_nights        adults      children        babies  \
# count          91531.000000  91531.000000  91527.000000  91531.000000
# mean               2.448438      1.835761      0.090968      0.008369
# std                1.935080      0.605828      0.373917      0.101749
# min                0.000000      0.000000      0.000000      0.000000
# 25%                1.000000      2.000000      0.000000      0.000000
# 50%                2.000000      2.000000      0.000000      0.000000
# 75%                3.000000      2.000000      0.000000      0.000000
# max               50.000000     55.000000     10.000000     10.000000
#
#        is_repeated_guest  previous_cancellations  \
# count       91531.000000            91531.000000
# mean            0.033890                0.110236
# std             0.180947                0.957503
# min             0.000000                0.000000
# 25%             0.000000                0.000000
# 50%             0.000000                0.000000
# 75%             0.000000                0.000000
# max             1.000000               26.000000
#
#        previous_bookings_not_canceled  booking_changes         agent  \
# count                    91531.000000     91531.000000  78314.000000
# mean                         0.134566         0.213480     83.343834
# std                          1.397675         0.635941    107.157625
# min                          0.000000         0.000000      1.000000
# 25%                          0.000000         0.000000      9.000000
# 50%                          0.000000         0.000000     14.000000
# 75%                          0.000000         0.000000    192.000000
# max                         61.000000        21.000000    510.000000
#
#            company  days_in_waiting_list           adr  \
# count  5614.000000          91531.000000  91531.000000
# mean    181.809939              2.962177     92.805250
# std     128.603363             19.925026     46.724693
# min       6.000000              0.000000     -6.380000
# 25%      51.000000              0.000000     65.000000
# 50%     174.000000              0.000000     86.400000
# 75%     242.000000              0.000000    114.000000
# max     523.000000            391.000000   5400.000000
#
#        required_car_parking_spaces  total_of_special_requests
# count                 91531.000000               91531.000000
# mean                      0.065519                   0.528346
# std                       0.250991                   0.766310
# min                       0.000000                   0.000000
# 25%                       0.000000                   0.000000
# 50%                       0.000000                   0.000000
# 75%                       0.000000                   1.000000
# max                       8.000000                   5.000000

# %%
# Looking for missing values (null and/or NaN)
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
plt.show()

# %%
# Print a summary of variables with null values
df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             468
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# agent                             13217
# company                           85917
# days_in_waiting_list                  0
# customer_type                         0
# adr                                   0
# required_car_parking_spaces           0
# total_of_special_requests             0
# dtype: int64

# %%
# More correlation
corr = df.corr()
corr
# ==Q== ¿Qué limitación encuentras en esta tabla?
# Out:
#                                 lead_time  arrival_date_year  \
# lead_time                        1.000000          -0.070732
# arrival_date_year               -0.070732           1.000000
# arrival_date_week_number         0.155992          -0.620153
# arrival_date_day_of_month       -0.009430           0.002929
# stays_in_weekend_nights          0.057351          -0.018536
# stays_in_week_nights             0.145017          -0.002270
# adults                           0.114516          -0.018630
# children                        -0.060137           0.025812
# babies                          -0.025167          -0.011692
# is_repeated_guest               -0.117214           0.034990
# previous_cancellations           0.111519          -0.116560
# previous_bookings_not_canceled  -0.071374           0.044190
# booking_changes                 -0.016268           0.026284
# agent                           -0.125697           0.043742
# company                          0.151244           0.257845
# days_in_waiting_list             0.205704          -0.017487
# adr                             -0.083224          -0.025174
# required_car_parking_spaces     -0.117076           0.001336
# total_of_special_requests       -0.137366           0.068772
#
#                                 arrival_date_week_number  \
# lead_time                                       0.155992
# arrival_date_year                              -0.620153
# arrival_date_week_number                        1.000000
# arrival_date_day_of_month                       0.054331
# stays_in_weekend_nights                         0.022775
# stays_in_week_nights                            0.015237
# adults                                          0.029081
# children                                       -0.000639
# babies                                          0.009022
# is_repeated_guest                              -0.036474
# previous_cancellations                          0.029807
# previous_bookings_not_canceled                 -0.026496
# booking_changes                                 0.004075
# agent                                          -0.031241
# company                                        -0.057809
# days_in_waiting_list                            0.015575
# adr                                             0.105584
# required_car_parking_spaces                    -0.002775
# total_of_special_requests                       0.031282
#
#                                 arrival_date_day_of_month  \
# lead_time                                       -0.009430
# arrival_date_year                                0.002929
# arrival_date_week_number                         0.054331
# arrival_date_day_of_month                        1.000000
# stays_in_weekend_nights                         -0.021686
# stays_in_week_nights                            -0.029915
# adults                                          -0.000042
# children                                         0.016613
# babies                                          -0.000338
# is_repeated_guest                               -0.005385
# previous_cancellations                          -0.031012
# previous_bookings_not_canceled                  -0.000049
# booking_changes                                  0.011077
# agent                                           -0.001554
# company                                          0.053169
# days_in_waiting_list                             0.025874
# adr                                              0.033686
# required_car_parking_spaces                      0.008862
# total_of_special_requests                        0.004652
#
#                                 stays_in_weekend_nights  stays_in_week_nights  \
# lead_time                                      0.057351              0.145017
# arrival_date_year                             -0.018536             -0.002270
# arrival_date_week_number                       0.022775              0.015237
# arrival_date_day_of_month                     -0.021686             -0.029915
# stays_in_weekend_nights                        1.000000              0.517161
# stays_in_week_nights                           0.517161              1.000000
# adults                                         0.089761              0.084698
# children                                       0.040299              0.036938
# babies                                         0.017438              0.016841
# is_repeated_guest                             -0.092898             -0.103593
# previous_cancellations                        -0.009460             -0.011113
# previous_bookings_not_canceled                -0.041479             -0.050100
# booking_changes                                0.073775              0.103896
# agent                                          0.126642              0.173179
# company                                        0.097765              0.191097
# days_in_waiting_list                          -0.058431              0.001383
# adr                                            0.037486              0.048650
# required_car_parking_spaces                   -0.018331             -0.026595
# total_of_special_requests                      0.075139              0.068818
#
#                                   adults  children    babies  \
# lead_time                       0.114516 -0.060137 -0.025167
# arrival_date_year              -0.018630  0.025812 -0.011692
# arrival_date_week_number        0.029081 -0.000639  0.009022
# arrival_date_day_of_month      -0.000042  0.016613 -0.000338
# stays_in_weekend_nights         0.089761  0.040299  0.017438
# stays_in_week_nights            0.084698  0.036938  0.016841
# adults                          1.000000  0.030126  0.019994
# children                        0.030126  1.000000  0.027086
# babies                          0.019994  0.027086  1.000000
# is_repeated_guest              -0.137987 -0.031518 -0.009471
# previous_cancellations          0.000663 -0.025355 -0.008460
# previous_bookings_not_canceled -0.104113 -0.020664 -0.006843
# booking_changes                -0.051519  0.048037  0.080451
# agent                          -0.039348  0.030731  0.036703
# company                         0.219433  0.035497  0.024929
# days_in_waiting_list           -0.003905 -0.034799 -0.012222
# adr                             0.198476  0.294647  0.037922
# required_car_parking_spaces     0.016953  0.063268  0.032005
# total_of_special_requests       0.122553  0.089923  0.104010
#
#                                 is_repeated_guest  previous_cancellations  \
# lead_time                               -0.117214                0.111519
# arrival_date_year                        0.034990               -0.116560
# arrival_date_week_number                -0.036474                0.029807
# arrival_date_day_of_month               -0.005385               -0.031012
# stays_in_weekend_nights                 -0.092898               -0.009460
# stays_in_week_nights                    -0.103593               -0.011113
# adults                                  -0.137987                0.000663
# children                                -0.031518               -0.025355
# babies                                  -0.009471               -0.008460
# is_repeated_guest                        1.000000                0.073088
# previous_cancellations                   0.073088                1.000000
# previous_bookings_not_canceled           0.413832                0.128712
# booking_changes                          0.009094               -0.030735
# agent                                    0.024725               -0.011313
# company                                 -0.237287               -0.173977
# days_in_waiting_list                    -0.025981                0.002727
# adr                                     -0.138654               -0.056475
# required_car_parking_spaces              0.068502               -0.023007
# total_of_special_requests                0.001424               -0.056001
#
#                                 previous_bookings_not_canceled  \
# lead_time                                            -0.071374
# arrival_date_year                                     0.044190
# arrival_date_week_number                             -0.026496
# arrival_date_day_of_month                            -0.000049
# stays_in_weekend_nights                              -0.041479
# stays_in_week_nights                                 -0.050100
# adults                                               -0.104113
# children                                             -0.020664
# babies                                               -0.006843
# is_repeated_guest                                     0.413832
# previous_cancellations                                0.128712
# previous_bookings_not_canceled                        1.000000
# booking_changes                                       0.013024
# agent                                                 0.021735
# company                                              -0.203653
# days_in_waiting_list                                 -0.011044
# adr                                                  -0.071360
# required_car_parking_spaces                           0.043570
# total_of_special_requests                             0.029086
#
#                                 booking_changes     agent   company  \
# lead_time                             -0.016268 -0.125697  0.151244
# arrival_date_year                      0.026284  0.043742  0.257845
# arrival_date_week_number               0.004075 -0.031241 -0.057809
# arrival_date_day_of_month              0.011077 -0.001554  0.053169
# stays_in_weekend_nights                0.073775  0.126642  0.097765
# stays_in_week_nights                   0.103896  0.173179  0.191097
# adults                                -0.051519 -0.039348  0.219433
# children                               0.048037  0.030731  0.035497
# babies                                 0.080451  0.036703  0.024929
# is_repeated_guest                      0.009094  0.024725 -0.237287
# previous_cancellations                -0.030735 -0.011313 -0.173977
# previous_bookings_not_canceled         0.013024  0.021735 -0.203653
# booking_changes                        1.000000  0.068828  0.129543
# agent                                  0.068828  1.000000  0.430367
# company                                0.129543  0.430367  1.000000
# days_in_waiting_list                  -0.013164 -0.062414 -0.007491
# adr                                    0.007410 -0.065492  0.017394
# required_car_parking_spaces            0.060834  0.186292 -0.010881
# total_of_special_requests              0.040245  0.043028 -0.085697
#
#                                 days_in_waiting_list       adr  \
# lead_time                                   0.205704 -0.083224
# arrival_date_year                          -0.017487 -0.025174
# arrival_date_week_number                    0.015575  0.105584
# arrival_date_day_of_month                   0.025874  0.033686
# stays_in_weekend_nights                    -0.058431  0.037486
# stays_in_week_nights                        0.001383  0.048650
# adults                                     -0.003905  0.198476
# children                                   -0.034799  0.294647
# babies                                     -0.012222  0.037922
# is_repeated_guest                          -0.025981 -0.138654
# previous_cancellations                      0.002727 -0.056475
# previous_bookings_not_canceled             -0.011044 -0.071360
# booking_changes                            -0.013164  0.007410
# agent                                      -0.062414 -0.065492
# company                                    -0.007491  0.017394
# days_in_waiting_list                        1.000000 -0.021974
# adr                                        -0.021974  1.000000
# required_car_parking_spaces                -0.035900  0.062632
# total_of_special_requests                  -0.088337  0.143661
#
#                                 required_car_parking_spaces  \
# lead_time                                         -0.117076
# arrival_date_year                                  0.001336
# arrival_date_week_number                          -0.002775
# arrival_date_day_of_month                          0.008862
# stays_in_weekend_nights                           -0.018331
# stays_in_week_nights                              -0.026595
# adults                                             0.016953
# children                                           0.063268
# babies                                             0.032005
# is_repeated_guest                                  0.068502
# previous_cancellations                            -0.023007
# previous_bookings_not_canceled                     0.043570
# booking_changes                                    0.060834
# agent                                              0.186292
# company                                           -0.010881
# days_in_waiting_list                              -0.035900
# adr                                                0.062632
# required_car_parking_spaces                        1.000000
# total_of_special_requests                          0.083928
#
#                                 total_of_special_requests
# lead_time                                       -0.137366
# arrival_date_year                                0.068772
# arrival_date_week_number                         0.031282
# arrival_date_day_of_month                        0.004652
# stays_in_weekend_nights                          0.075139
# stays_in_week_nights                             0.068818
# adults                                           0.122553
# children                                         0.089923
# babies                                           0.104010
# is_repeated_guest                                0.001424
# previous_cancellations                          -0.056001
# previous_bookings_not_canceled                   0.029086
# booking_changes                                  0.040245
# agent                                            0.043028
# company                                         -0.085697
# days_in_waiting_list                            -0.088337
# adr                                              0.143661
# required_car_parking_spaces                      0.083928
# total_of_special_requests                        1.000000

# %%
# Plot the correlation matrix
sns.heatmap(corr, vmax=.3, center=0, cmap='jet', square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()
